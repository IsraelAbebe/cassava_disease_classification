# %%
# !pip install pretrainedmodels

# %%
import pretrainedmodels

# %%
import os

# %%
os.listdir("./data/train/train")
# Out:
# ['cmd', 'healthy', 'cbsd', 'cbb', 'cgm']

# %%
os.listdir("./data/train/train/cgm")[:10]
# Out:
# ['train-cgm-100.jpg',
#  'train-cgm-155.jpg',
#  'train-cgm-193.jpg',
#  'train-cgm-391.jpg',
#  'train-cgm-200.jpg',
#  'train-cgm-484.jpg',
#  'train-cgm-12.jpg',
#  'train-cgm-599.jpg',
#  'train-cgm-63.jpg',
#  'train-cgm-477.jpg']

# %%
os.listdir("./data/test/test/0")[:10]
# Out:
# ['test-img-1551.jpg',
#  'test-img-311.jpg',
#  'test-img-600.jpg',
#  'test-img-1092.jpg',
#  'test-img-156.jpg',
#  'test-img-3555.jpg',
#  'test-img-2170.jpg',
#  'test-img-3393.jpg',
#  'test-img-1523.jpg',
#  'test-img-2519.jpg']

# %%
from fastai import *
from fastai.vision import *

import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import auc,roc_curve

from math import floor

# %%
train_path = "./data/train/train"
test_path = "./data/test/test/0"

# %%
def get_labels(file_path): 
    dir_name = os.path.dirname(file_path)
    split_dir_name = dir_name.split("/")
    dir_levels = len(split_dir_name)
    label  = split_dir_name[dir_levels - 1]
    return(label)

# %%
get_labels("./data/train/train/cgm/train-cgm-528.jpg")
# Out:
# 'cgm'

# %%
from glob import glob
imagePatches = glob("./data/train/train/*/*.*", recursive=True)
imagePatches[0:10]
# Out:
# ['./data/train/train/cmd/train-cmd-634.jpg',
#  './data/train/train/cmd/train-cmd-1039.jpg',
#  './data/train/train/cmd/train-cmd-2023.jpg',
#  './data/train/train/cmd/train-cmd-73.jpg',
#  './data/train/train/cmd/train-cmd-1933.jpg',
#  './data/train/train/cmd/train-cmd-449.jpg',
#  './data/train/train/cmd/train-cmd-2276.jpg',
#  './data/train/train/cmd/train-cmd-1450.jpg',
#  './data/train/train/cmd/train-cmd-674.jpg',
#  './data/train/train/cmd/train-cmd-1204.jpg']

# %%
path=""
tfms = get_transforms()

# %%
data = ImageDataBunch.from_name_func(path, imagePatches, label_func=get_labels,  size=500, 
                                     bs=16,num_workers=2,test = test_path,ds_tfms=tfms
                                  ).normalize(imagenet_stats)

# %%
type(data)
# Out:
# fastai.vision.data.ImageDataBunch

# %%
data.show_batch(rows=3, figsize=(8,8))

# %%
def se_resnext50_32x4d(pretrained=False):
    pretrained = 'imagenet' if pretrained else None
    model = pretrainedmodels.se_resnext50_32x4d(pretrained=pretrained)
    return model

# %%
learner = cnn_learner(data, se_resnext50_32x4d, pretrained=True,
                   cut=-2, split_on=lambda m: (m[0][3], m[1]),metrics = [accuracy])

# %%
learner.lr_find()
learner.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='89' class='' max='282' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       31.56% [89/282 00:38<01:24 7.1590]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=1e-1
learner.fit_one_cycle(1, lr)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.594420</td>
#       <td>1.157291</td>
#       <td>0.620690</td>
#       <td>02:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.save('model-1')

# %%
learner.unfreeze()

# %%
learner.lr_find()
learner.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='86' class='' max='282' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       30.50% [86/282 00:35<01:20 3.7806]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learner.freeze_to(-2)

# %%
learner.lr_find()
learner.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='86' class='' max='282' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       30.50% [86/282 00:34<01:18 3.7813]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learner.fit_one_cycle(80, 1e-5)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='31' class='' max='80' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       38.75% [31/80 1:02:26<1:38:41]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.169142</td>
#       <td>2.621517</td>
#       <td>0.619805</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.196255</td>
#       <td>5.670571</td>
#       <td>0.606543</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.157785</td>
#       <td>4.405372</td>
#       <td>0.626879</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.183695</td>
#       <td>8.593189</td>
#       <td>0.625995</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.123902</td>
#       <td>1.273701</td>
#       <td>0.632184</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.124823</td>
#       <td>3.831984</td>
#       <td>0.636605</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.104825</td>
#       <td>5.255794</td>
#       <td>0.630416</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.104684</td>
#       <td>17.055525</td>
#       <td>0.631300</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.077785</td>
#       <td>14.573171</td>
#       <td>0.634836</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.100443</td>
#       <td>16.744617</td>
#       <td>0.636605</td>
#       <td>01:59</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.062090</td>
#       <td>10.063038</td>
#       <td>0.642794</td>
#       <td>01:59</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.029509</td>
#       <td>12.576639</td>
#       <td>0.655172</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.044260</td>
#       <td>17.429903</td>
#       <td>0.662246</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.963842</td>
#       <td>12.108902</td>
#       <td>0.678161</td>
#       <td>02:02</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.983708</td>
#       <td>63.635052</td>
#       <td>0.675508</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.977857</td>
#       <td>4.391681</td>
#       <td>0.693192</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.913856</td>
#       <td>25.711689</td>
#       <td>0.684350</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.908815</td>
#       <td>21.091095</td>
#       <td>0.687003</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.846398</td>
#       <td>146.589569</td>
#       <td>0.705570</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.840613</td>
#       <td>55.545818</td>
#       <td>0.708223</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.843712</td>
#       <td>434.165741</td>
#       <td>0.704686</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.864586</td>
#       <td>40.577282</td>
#       <td>0.726790</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.863109</td>
#       <td>8.814753</td>
#       <td>0.718833</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.789770</td>
#       <td>35.048084</td>
#       <td>0.726790</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.853370</td>
#       <td>22.202230</td>
#       <td>0.728559</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.824103</td>
#       <td>10.107486</td>
#       <td>0.729443</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.774787</td>
#       <td>40.022690</td>
#       <td>0.728559</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.757325</td>
#       <td>77.664413</td>
#       <td>0.739169</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.800099</td>
#       <td>63.345890</td>
#       <td>0.736516</td>
#       <td>02:02</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.779235</td>
#       <td>35.401005</td>
#       <td>0.719717</td>
#       <td>01:59</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.736977</td>
#       <td>186.946930</td>
#       <td>0.727675</td>
#       <td>02:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='30' class='' max='282' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       10.64% [30/282 00:12<01:46 0.7174]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-98af8792bcad> in <module>()
# ----> 1 learner.fit_one_cycle(80, 1e-5)
#
# ~/anaconda3/envs/aws_neuron_mxnet_p36/lib/python3.6/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, final_div, wd, callbacks, tot_epochs, start_epoch)
#      21     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start,
#      22                                        final_div=final_div, tot_epochs=tot_epochs, start_epoch=start_epoch))
# ---> 23     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      24
#      25 def fit_fc(learn:Learner, tot_epochs:int=1, lr:float=defaults.lr,  moms:Tuple[float,float]=(0.95,0.85), start_pct:float=0.72,
#
# ~/anaconda3/envs/aws_neuron_mxnet_p36/lib/python3.6/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     198         else: self.opt.lr,self.opt.wd = lr,wd
#     199         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
# --> 200         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     201
#     202     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/anaconda3/envs/aws_neuron_mxnet_p36/lib/python3.6/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      99             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     102                 if cb_handler.on_batch_end(loss): break
#     103
#
# ~/anaconda3/envs/aws_neuron_mxnet_p36/lib/python3.6/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      33         loss,skip_bwd = cb_handler.on_backward_begin(loss)
#      34         if not skip_bwd:                     loss.backward()
# ---> 35         if not cb_handler.on_backward_end(): opt.step()
#      36         if not cb_handler.on_step_end():     opt.zero_grad()
#      37
#
# ~/anaconda3/envs/aws_neuron_mxnet_p36/lib/python3.6/site-packages/fastai/callback.py in step(self)
#      55                     for p in pg2['params']: p.data.mul_(1 - wd*lr)
#      56             self.set_val('weight_decay', listify(0, self._wd))
# ---> 57         self.opt.step()
#      58
#      59     def zero_grad(self)->None:
#
# ~/anaconda3/envs/aws_neuron_mxnet_p36/lib/python3.6/site-packages/torch/optim/adam.py in step(self, closure)
#      93
#      94                 # Decay the first and second moment running average coefficient
# ---> 95                 exp_avg.mul_(beta1).add_(1 - beta1, grad)
#      96                 exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
#      97                 if amsgrad:
#
# KeyboardInterrupt:

# %%
learner.recorder.plot_losses()

# %%
learner.validate()
# Out:
# [108.11191, tensor(0.7577)]

# %%
interp = ClassificationInterpretation.from_learner(learner)

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.most_confused(min_val=2)
# Out:
# [('cbb', 'cbsd', 73),
#  ('cgm', 'cmd', 61),
#  ('cmd', 'cbsd', 21),
#  ('cbb', 'cmd', 20),
#  ('healthy', 'cmd', 19),
#  ('healthy', 'cbsd', 16),
#  ('cmd', 'cgm', 12),
#  ('cgm', 'cbsd', 11),
#  ('cbsd', 'cmd', 9),
#  ('cbb', 'cgm', 6),
#  ('cbsd', 'cgm', 6),
#  ('cmd', 'cbb', 6),
#  ('healthy', 'cgm', 5),
#  ('cbsd', 'cbb', 4),
#  ('cgm', 'healthy', 2),
#  ('cmd', 'healthy', 2)]

# %%
preds,y = learner.TTA(ds_type=DatasetType.Test)

# %%
len(preds)
# Out:
# 3774

# %%
len(os.listdir(test_path))
# Out:
# 3774

# %%
SAMPLE_SUB = './data/sample_submission_file.csv'
sample_df = pd.read_csv(SAMPLE_SUB)

# %%
sample_df.head()
# Out:
#   Category              Id
# 0     cbsd  test-img-0.jpg
# 1      cmd  test-img-1.jpg
# 2      cbb  test-img-2.jpg
# 3      cmd  test-img-3.jpg
# 4     cbsd  test-img-4.jpg

# %%
predictions = preds.numpy()

# %%
class_preds = np.argmax(predictions, axis=1)

# %%
for c, i in learner.data.train_ds.y.c2i.items():
    print(c,i)
# Out:
# cbb 0
# cbsd 1
# cgm 2
# cmd 3
# healthy 4

# %%
categories = ['cbb','cbsd','cgm','cmd','healthy']

def map_to_categories(predictions):
    return(categories[predictions])

categories_preds = list(map(map_to_categories,class_preds))

# %%
filenames = list(map(os.path.basename,os.listdir(test_path)))

# %%
df_sub = pd.DataFrame({'Category':categories_preds,'Id':filenames})

# %%
df_sub.head()
# Out:
#   Category                 Id
# 0      cmd  test-img-1551.jpg
# 1      cmd   test-img-311.jpg
# 2      cmd   test-img-600.jpg
# 3      cmd  test-img-1092.jpg
# 4      cbb   test-img-156.jpg

# %%
# Export to csv
df_sub.to_csv('submission_categories.csv', header=True, index=False)
